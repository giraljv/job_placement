# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import utils.data_cleaning

# %%
# %run './0-0_job_placement_data_download.ipynb'

# %%
df
# Out:
#     gender  ssc_percentage ssc_board  hsc_percentage hsc_board hsc_subject  \
# 0        M           67.00    Others           91.00    Others    Commerce
# 1        M           79.33   Central           78.33    Others     Science
# 2        M           65.00   Central           68.00   Central        Arts
# 3        M           56.00   Central           52.00   Central     Science
# 4        M           85.80   Central           73.60   Central    Commerce
# ..     ...             ...       ...             ...       ...         ...
# 210      M           80.60    Others           82.00    Others    Commerce
# 211      M           58.00    Others           60.00    Others     Science
# 212      M           67.00    Others           67.00    Others    Commerce
# 213      F           74.00    Others           66.00    Others    Commerce
# 214      M           62.00   Central           58.00    Others     Science
#
# ...

# %% [markdown]
# ## Cambiando valores de features a numericos

# %%
df_processed = df.copy()

# %%
df_processed['gender'] = df_processed['gender'].replace(to_replace=['M','F'],value=[0,1])
df_processed['ssc_board'] = df_processed['ssc_board'].replace(to_replace=['Others','Central'],value=[0,1])
df_processed['hsc_subject'] = df_processed['hsc_subject'].replace(to_replace=['Commerce', 'Science', 'Arts'],value=[0,1,2])
df_processed['undergrad_degree'] = df_processed['undergrad_degree'].replace(to_replace=['Sci&Tech', 'Comm&Mgmt', 'Others'],value=[0,1,2])
df_processed['work_experience'] = df_processed['work_experience'].replace(to_replace=['No','Yes'],value=[0,1])
df_processed['specialisation'] = df_processed['specialisation'].replace(to_replace=['Mkt&HR', 'Mkt&Fin'],value=[0,1])
df_processed['status'] = df_processed['status'].replace(to_replace=['Placed', 'Not Placed'],value=[0,1])

# %%
df_processed.to_csv(
    path_or_buf='../data/processed/job_placement.csv',
    index=False,
    sep=','
)

# %% [markdown]
# ## valores nulos

# %%
df_processed.ms_tools.number_missing()
# Out:
# 0

# %%
df_processed.ms_tools.vis_proportion()
plt.title('Valores nulos por feature:')
plt.show()
