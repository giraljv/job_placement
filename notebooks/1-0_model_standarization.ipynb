# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../data/processed/jp_for_model.csv')
df.head(3)
# Out:
#    gender  ssc_percentage  ssc_board  hsc_percentage  hsc_board  hsc_subject  \
# 0       0           79.33          1           78.33          0            1
# 1       0           65.00          1           68.00          1            2
# 2       0           56.00          1           52.00          1            1
#
#    degree_percentage  undergrad_degree  work_experience  emp_test_percentage  \
# 0              77.48                 0                1                 86.5
# 1              64.00                 1                0                 75.0
# 2              52.00                 0                0                 66.0
#
#    specialisation  mba_percent  status
# 0               1        66.28       0
# 1               1        57.80       0
# 2               0        59.43       1

# %% [markdown]
# ## Escalamiento de datos

# %%
scaler = StandardScaler()

# %%
# Escalamiento de los datos x
df_scaled = scaler.fit_transform(df.drop('status',axis=1))
df_scaled = pd.DataFrame(df_scaled)
df_scaled['status'] = df['status']
df_scaled.columns = df.columns
df_scaled
# Out:
#        gender  ssc_percentage  ssc_board  hsc_percentage  hsc_board  \
# 0   -0.738549        1.127071   0.897391        1.274342  -0.819836
# 1   -0.738549       -0.227165   0.897391        0.173501   1.219756
# 2   -0.738549       -1.077698   0.897391       -1.531577   1.219756
# 3   -0.738549        1.738510   0.897391        0.770278   1.219756
# 4   -0.738549       -1.172202  -1.114342       -1.766025  -0.819836
# ..        ...             ...        ...             ...        ...
# 199 -0.738549        1.247091  -1.114342        1.665444  -0.819836
# 200 -0.738549       -0.888691  -1.114342       -0.679038  -0.819836
# 201 -0.738549       -0.038158  -1.114342        0.066934  -0.819836
# 202  1.354006        0.623367  -1.114342       -0.039634  -0.819836
# 203 -0.738549       -0.510676   0.897391       -0.892172  -0.819836
#
#      hsc_subject  degree_percentage  undergrad_degree  work_experience  \
# 0       0.831028           1.576083         -1.528069         1.354006
# ...

# %% [markdown]
# ## split de datos

# %%
x = df_scaled.drop('status',axis=1)
y = df_scaled['status']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.35,random_state=42)
#print(f'shape de x_train = {x_train.shape} and shape de x_test = {x_test.shape}')
#print(f'shape de y_train = {y_train.shape} and shape de y_test = {y_test.shape}')
